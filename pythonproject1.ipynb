# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("myexcel.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
x = data['Salary'].median()
data['Salary'].fillna(x, inplace = True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data['Height'] = np.random.uniform(150, 180, size = len(data))
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  168.522439     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  167.869543     235
# 2     John Holland  Boston Celtics      30       SG   27  158.328473     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  175.973092     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  151.491125     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  163.696921     203
# 454      Raul Neto       Utah Jazz      25       PG   24  151.066513     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  165.118540     256
# 456    Jeff Withey       Utah Jazz      24        C   26  161.371124     231
# 457       Priyanka       Utah Jazz      34        C   25  160.189703     231
#
#                College     Salary
# ...

# %% [markdown]
# # 1

# %%
group = data.groupby('Team')
group

# %%
for Team in group:
    print(Team)
# Out:
# ('Atlanta Hawks',                  Name           Team  Number Position  Age      Height  \
# 309     Kent Bazemore  Atlanta Hawks      24       SF   26  176.210590
# 310  Tim Hardaway Jr.  Atlanta Hawks      10       SG   24  174.048019
# 311      Kirk Hinrich  Atlanta Hawks      12       SG   35  161.636024
# 312        Al Horford  Atlanta Hawks      15        C   30  176.425633
# 313    Kris Humphries  Atlanta Hawks      43       PF   31  179.199139
# 314       Kyle Korver  Atlanta Hawks      26       SG   35  173.954615
# 315      Paul Millsap  Atlanta Hawks       4       PF   31  161.363614
# 316      Mike Muscala  Atlanta Hawks      31       PF   24  171.563798
# 317   Lamar Patterson  Atlanta Hawks      13       SG   24  176.865562
# 318   Dennis Schroder  Atlanta Hawks      17       PG   22  158.278664
# 319        Mike Scott  Atlanta Hawks      32       PF   27  160.066182
# 320   Thabo Sefolosha  Atlanta Hawks      25       SF   32  168.384127
# ...

# %%
group.max(Team)
# Out:
#                         Number  Age      Height  Weight      Salary
# Team
# Atlanta Hawks               43   35  179.304278     260  18671659.0
# Boston Celtics              99   29  177.170015     260  12000000.0
# Brooklyn Nets               44   32  178.971609     275  19689000.0
# Charlotte Hornets           50   31  179.884964     289  13500000.0
# Chicago Bulls               55   35  179.658345     275  20093064.0
# Cleveland Cavaliers         52   35  178.939026     275  22970500.0
# Dallas Mavericks            50   37  179.811398     275  16407500.0
# Denver Nuggets              77   36  179.337224     280  14000000.0
# Detroit Pistons             50   36  178.243520     279  16000000.0
# Golden State Warriors       40   33  179.618810     273  15501000.0
# Houston Rockets             35   38  175.750572     265  22359364.0
# Indiana Pacers              44   30  179.817677     255  17120106.0
# Los Angeles Clippers        45   39  176.921390     265  21468695.0
# ...

# %%
percentage_of_employees = data['Team'].value_counts(normalize=True) * 100
print(percentage_of_employees)
# Out:
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# Philadelphia 76ers        3.275109
# ...

# %% [markdown]
# # 2

# %%
groups = data.groupby(['Position','Name'])
group

# %%
for position, Name in groups:
    print(position)
# Out:
# ('C', 'Al Horford')
# ('C', 'Al Jefferson')
# ('C', 'Alan Williams')
# ('C', 'Alex Len')
# ('C', 'Alexis Ajinca')
# ('C', 'Andre Drummond')
# ('C', 'Andrew Bogut')
# ('C', 'Aron Baynes')
# ('C', 'Bismack Biyombo')
# ('C', 'Boban Marjanovic')
# ('C', 'Boris Diaw')
# ('C', 'Brook Lopez')
# ('C', 'Chris Kaman')
# ('C', 'Cody Zeller')
# ('C', 'Cole Aldrich')
# ('C', 'DeAndre Jordan')
# ('C', 'DeMarcus Cousins')
# ('C', 'Dewayne Dedmon')
# ('C', 'Dwight Howard')
# ('C', 'Ed Davis')
# ('C', 'Enes Kanter')
# ('C', 'Festus Ezeli')
# ('C', 'Frank Kaminsky III')
# ('C', 'Gorgui Dieng')
# ('C', 'Greg Monroe')
# ('C', 'Hassan Whiteside')
# ('C', 'Henry Sims')
# ('C', 'Ian Mahinmi')
# ('C', 'JJ Hickson')
# ('C', 'JaVale McGee')
# ('C', 'Jahlil Okafor')
# ('C', 'Jared Sullinger')
# ('C', 'Jeff Withey')
# ('C', 'Joakim Noah')
# ('C', 'Joel Anthony')
# ('C', 'Joel Embiid')
# ('C', 'Joffrey Lauvergne')
# ('C', 'Jonas Valanciunas')
# ('C', 'Jordan Hill')
# ('C', 'Josh Smith')
# ('C', 'Jusuf Nurkic')
# ...

# %% [markdown]
# # 3

# %%
data['Age Group'] = [
    '20-25' if age < 25 else
    '25-30' if age < 30 else
    '30-35' if age < 35 else
    '35-40' if age < 40 else
    '40-45' if age < 45 else
    '45-50'
    for age in data['Age']
]
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  168.522439     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  167.869543     235
# 2     John Holland  Boston Celtics      30       SG   27  158.328473     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  175.973092     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  151.491125     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  163.696921     203
# 454      Raul Neto       Utah Jazz      25       PG   24  151.066513     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  165.118540     256
# 456    Jeff Withey       Utah Jazz      24        C   26  161.371124     231
# 457       Priyanka       Utah Jazz      34        C   25  160.189703     231
#
#                College     Salary Age Group
# ...

# %%
data['Age Group'].value_counts()
# Out:
# 25-30    182
# 20-25    154
# 30-35     90
# 35-40     29
# 40-45      3
# Name: Age Group, dtype: int64

# %% [markdown]
# # 4

# %%
groups = data.groupby(["Team","Position"])
groups

# %%
salary = groups["Salary"].sum()
salary.idxmax()
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# # 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation = data['Salary'].corr(data['Age'])
print("Correlation : ",correlation)
# Out:
# Correlation :  0.20912419115196068

# %%
plt.scatter(data['Salary'], data['Age'], color="purple")
plt.xlabel("Salary")
plt.ylabel("Age")
plt.title("Correlation between Age and Salary")
plt.show()
